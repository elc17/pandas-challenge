# %%
# Import Dependencies
import os
import csv
import pandas as pd

# %%
# Create a path to the csv and read it into a Pandas DataFrame
csv_path = "ted_talks.csv"
ted_df = pd.read_csv(csv_path)

ted_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event  languages   main_speaker  \
# 0  TED2006         60   Ken Robinson
# 1  TED2006         43        Al Gore
# 2  TED2006         26    David Pogue
# 3  TED2006         35  Majora Carter
# 4  TED2006         48   Hans Rosling
#
#                                             name  \
# 0      Ken Robinson: Do schools kill creativity?
# 1           Al Gore: Averting the climate crisis
# 2                  David Pogue: Simplicity sells
# 3             Majora Carter: Greening the ghetto
# 4  Hans Rosling: The best stats you've ever seen
#
#                              title     views
# 0      Do schools kill creativity?  47227110
# 1      Averting the climate crisis   3200520
# 2                 Simplicity sells   1636292
# 3              Greening the ghetto   1697550
# 4  The best stats you've ever seen  12005869

# %%
# Figure out the minimum and maximum views for a TED Talk
maxv = ted_df["views"].max()
minv = ted_df["views"].min()
# Out:
# 47227110

# %%
# Create bins in which to place values based upon TED Talk views
step = int((maxv-minv)/10)
bins = []
for i in range(minv, maxv, step):
    bins.append(i)
print(bins)
print(step)
# Create labels for these bins
labels = ["50443 - 4768109", "4768109 - 9485775", "9485775 - 14203441", "14203441 - 18921107", "18921107 - 23638773",
          "23638773 - 28356439", "28356439 - 33074105", "33074105 - 37791771", "37791771 - 42509437", "42509437 - 47227103"]
# Out:
# [50443, 4768109, 9485775, 14203441, 18921107, 23638773, 28356439, 33074105, 37791771, 42509437, 47227103]
# 4717666

# %%
# Slice the data and place it into bins
pd.cut(ted_df["views"], bins = bins, labels = labels).head()
# Out:
# 0                   NaN
# 1       50443 - 4768109
# 2       50443 - 4768109
# 3       50443 - 4768109
# 4    9485775 - 14203441
# Name: views, dtype: category
# Categories (10, object): [50443 - 4768109 < 4768109 - 9485775 < 9485775 - 14203441 < 14203441 - 18921107 ... 28356439 - 33074105 < 33074105 - 37791771 < 37791771 - 42509437 < 42509437 - 47227103]

# %%
# Place the data series into a new column inside of the DataFrame
ted_df["View group"] = pd.cut(ted_df["views"], bins = bins, labels = labels)
ted_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event  languages   main_speaker  \
# 0  TED2006         60   Ken Robinson
# 1  TED2006         43        Al Gore
# 2  TED2006         26    David Pogue
# 3  TED2006         35  Majora Carter
# 4  TED2006         48   Hans Rosling
#
#                                             name  \
# 0      Ken Robinson: Do schools kill creativity?
# 1           Al Gore: Averting the climate crisis
# 2                  David Pogue: Simplicity sells
# 3             Majora Carter: Greening the ghetto
# 4  Hans Rosling: The best stats you've ever seen
#
#                              title     views          View group
# 0      Do schools kill creativity?  47227110                 NaN
# 1      Averting the climate crisis   3200520     50443 - 4768109
# 2                 Simplicity sells   1636292     50443 - 4768109
# 3              Greening the ghetto   1697550     50443 - 4768109
# 4  The best stats you've ever seen  12005869  9485775 - 14203441

# %%
# Create a GroupBy object based upon "View Group"
ted_view_df = ted_df.groupby(["View group"])

# Find how many rows fall into each bin
print(ted_view_df["View group"].count())

# Get the average of each column within the GroupBy object
ted_view_df[["comments", "duration", "languages"]].mean()
# Out:
# View group
# 50443 - 4768109        2435
# 4768109 - 9485775        78
# 9485775 - 14203441       15
# 14203441 - 18921107      11
# 18921107 - 23638773       6
# 23638773 - 28356439       0
# 28356439 - 33074105       1
# 33074105 - 37791771       1
# 37791771 - 42509437       0
# 42509437 - 47227103       1
# Name: View group, dtype: int64
#                         comments     duration  languages
# View group
# 50443 - 4768109       172.064887   823.062012  26.758111
# 4768109 - 9485775     434.897436   844.410256  38.000000
# 9485775 - 14203441    779.600000   910.000000  42.800000
# 14203441 - 18921107   724.909091   950.818182  41.727273
# 18921107 - 23638773   866.000000   861.666667  42.166667
# 23638773 - 28356439          NaN          NaN        NaN
# 28356439 - 33074105  1927.000000  1219.000000  52.000000
# 33074105 - 37791771  1930.000000  1084.000000  45.000000
# 37791771 - 42509437          NaN          NaN        NaN
# 42509437 - 47227103  2290.000000  1262.000000  51.000000
